# %%
import pandas as pd
import datetime as dt

# %%
someday=dt.date(2020,1,20)

# %%
print("Year:: ",someday.year)
print("Month:: ",someday.month)
print("Day:: ",someday.day)
# Out:
# Year::  2020
# Month::  1
# Day::  20

# %%
m=str(someday)

# %%
type(m)
# Out:
# str

# %%
str(dt.datetime(2021,1,20,17,13,57))
# Out:
# '2021-01-20 17:13:57'

# %%
sometime=dt.datetime(2021,1,20,17,13,57)

print(sometime.year)
print(sometime.month)
print(sometime.day)
print(sometime.hour)
print(sometime.minute)
print(sometime.second)
# Out:
# 2021
# 1
# 20
# 17
# 13
# 57

# %%
## Pandas Timestamp object

# %%
print(pd.Timestamp("2015-03-31"))
print(pd.Timestamp("2015/03/31"))
print(pd.Timestamp("2/1/2015"))
print(pd.Timestamp("4/3/2000"))
print(pd.Timestamp("2021-03-08 08:35:15"))
# Out:
# 2015-03-31 00:00:00
# 2015-03-31 00:00:00
# 2015-02-01 00:00:00
# 2000-04-03 00:00:00
# 2021-03-08 08:35:15

# %%
pd.Timestamp(dt.datetime(2015,3,31))
# Out:
# Timestamp('2015-03-31 00:00:00')

# %%
# Pandas DateTime index object

# %%
dates=[dt.date(2021,1,10),dt.date(1994,6,3),dt.date(2003,12,29)]

# %%
dt_index=pd.DatetimeIndex(dates)
dt_index
# Out:
# DatetimeIndex(['2021-01-10', '1994-06-03', '2003-12-29'], dtype='datetime64[ns]', freq=None)

# %%
values=[1000,200,3000]
a=pd.Series(values,dt_index)
a
# Out:
# 2021-01-10    1000
# 1994-06-03     200
# 2003-12-29    3000
# dtype: int64

# %%
##pd.to_datetime() Method

# %%
print(pd.to_datetime("2008-04-19"))
print(pd.to_datetime(dt.date(2021,10,28)))
print(pd.to_datetime(dt.datetime(2016,10,12,22,14,52)))
# Out:
# 2008-04-19 00:00:00
# 2021-10-28 00:00:00
# 2016-10-12 22:14:52

# %%
times=pd.Series([dt.datetime(2015,1,2),"2014/02/08","2016","july 4,1996"])

# %%
pd.to_datetime(times)
# Out:
# 0   2015-01-02
# 1   2014-02-08
# 2   2016-01-01
# 3   1996-07-04
# dtype: datetime64[ns]

# %%
dates=pd.Series

# %%
## pd.period()

# %%
pd.Period("2021-10-20",freq="w")
# Out:
# Period('2021-10-18/2021-10-24', 'W-SUN')

# %%
# pd.Period("2016-01-08",freq="w-wed")
# Out:
# Period('2016-01-07/2016-01-13', 'W-WED')

# %%
##pd.PeriodIndex

# %%
pd.Series([1,2,3],index=pd.PeriodIndex(dates,freq="2M"))
# Out:
# 2021-01    1
# 1994-06    2
# 2003-12    3
# Freq: 2M, dtype: int64

# %%
## Create range of dates with pd.date_range() Method

# %%
times=pd.date_range(start="2016-01-01",end="2019-01-10",freq="D")
times
# Out:
# DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                '2016-01-09', '2016-01-10',
#                ...
#                '2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10'],
#               dtype='datetime64[ns]', length=1106, freq='D')

# %%
times=pd.date_range(start="2016-01-01",end="2019-01-10",freq="6H")
times
# Out:
# DatetimeIndex(['2016-01-01 00:00:00', '2016-01-01 06:00:00',
#                '2016-01-01 12:00:00', '2016-01-01 18:00:00',
#                '2016-01-02 00:00:00', '2016-01-02 06:00:00',
#                '2016-01-02 12:00:00', '2016-01-02 18:00:00',
#                '2016-01-03 00:00:00', '2016-01-03 06:00:00',
#                ...
#                '2019-01-07 18:00:00', '2019-01-08 00:00:00',
#                '2019-01-08 06:00:00', '2019-01-08 12:00:00',
#                '2019-01-08 18:00:00', '2019-01-09 00:00:00',
#                '2019-01-09 06:00:00', '2019-01-09 12:00:00',
#                '2019-01-09 18:00:00', '2019-01-10 00:00:00'],
#               dtype='datetime64[ns]', length=4421, freq='6H')

# %%
pd.date_range(start="2012-09-09",periods=120,freq="6H")
# Out:
# DatetimeIndex(['2012-09-09 00:00:00', '2012-09-09 06:00:00',
#                '2012-09-09 12:00:00', '2012-09-09 18:00:00',
#                '2012-09-10 00:00:00', '2012-09-10 06:00:00',
#                '2012-09-10 12:00:00', '2012-09-10 18:00:00',
#                '2012-09-11 00:00:00', '2012-09-11 06:00:00',
#                ...
#                '2012-10-06 12:00:00', '2012-10-06 18:00:00',
#                '2012-10-07 00:00:00', '2012-10-07 06:00:00',
#                '2012-10-07 12:00:00', '2012-10-07 18:00:00',
#                '2012-10-08 00:00:00', '2012-10-08 06:00:00',
#                '2012-10-08 12:00:00', '2012-10-08 18:00:00'],
#               dtype='datetime64[ns]', length=120, freq='6H')

# %%
pd.date_range(start="2012-09-09",periods=5,freq="6H")
# Out:
# DatetimeIndex(['2012-09-09 00:00:00', '2012-09-09 06:00:00',
#                '2012-09-09 12:00:00', '2012-09-09 18:00:00',
#                '2012-09-10 00:00:00'],
#               dtype='datetime64[ns]', freq='6H')
